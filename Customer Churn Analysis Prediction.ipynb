# %%
import numpy as np
import pandas as pd

# %%
dataset=pd.read_csv('telecom_data.csv')

# %%
dataset.head(5)
# Out:
#   State  Account Length  Area Code International Plan Voicemail Plan  \
# 0    TX              65        408                 No            Yes
# 1    KS             103        415                 No            Yes
# 2    OK             132        415                 No             No
# 3    OK             185        510                 No             No
# 4    FL             115        415                Yes             No
#
#    Number of Voicemail Messages  Total Day Minutes  Total Day Calls  \
# 0                             4              241.8              104
# 1                            11              122.6              115
# 2                            27              211.7              122
# 3                             2              243.6              108
# 4                             6              260.4              123
#
#    Total Day Charge  Total Eve Minutes  Total Eve Calls  Total Eve Charge  \
# 0             37.49              209.8               90             14.84
# 1             44.85              245.3              129             29.08
# 2             24.56              188.6              112             13.29
# 3             45.82              111.1              116             15.07
# 4             27.97              219.6               60             27.35
#
#    Total Night Minutes  Total Night Calls  Total Night Charge  \
# 0                160.8                 56               11.35
# 1                151.9                 58                7.60
# 2                235.5                131                5.66
# 3                184.8                123               11.97
# 4                137.8                107               10.90
#
#    Total Intl Minutes  Total Intl Calls  Total Intl Charge  \
# 0                13.5                 3               1.80
# 1                 7.5                 5               3.15
# 2                12.4                 6               1.66
# 3                 6.4                 2               3.69
# 4                14.5                 1               3.12
#
#    Customer service calls  Churn
# 0                     NaN  False
# 1                     NaN  False
# 2                     NaN  False
# 3                     NaN   True
# 4                     NaN  False

# %%
dataset.isnull().sum()
# Out:
# State                             0
# Account Length                    0
# Area Code                         0
# International Plan                0
# Voicemail Plan                    0
# Number of Voicemail Messages      0
# Total Day Minutes                 0
# Total Day Calls                   0
# Total Day Charge                  0
# Total Eve Minutes                 0
# Total Eve Calls                   0
# Total Eve Charge                  0
# Total Night Minutes               0
# Total Night Calls                 0
# Total Night Charge                0
# Total Intl Minutes                0
# Total Intl Calls                  0
# Total Intl Charge                 0
# Customer service calls          500
# Churn                             0
# dtype: int64

# %%
dataset['Customer service calls'] = dataset['Customer service calls'].fillna(pd.Series(np.random.randint(0, 10, size=len(dataset))))

# %%
dataset
# Out:
#     State  Account Length  Area Code International Plan Voicemail Plan  \
# 0      TX              65        408                 No            Yes
# 1      KS             103        415                 No            Yes
# 2      OK             132        415                 No             No
# 3      OK             185        510                 No             No
# 4      FL             115        415                Yes             No
# ..    ...             ...        ...                ...            ...
# 495    IL              91        415                 No            Yes
# 496    KS             153        510                 No             No
# 497    FL              98        415                 No             No
# 498    NY             177        415                Yes             No
# 499    TX             188        415                 No            Yes
#
#      Number of Voicemail Messages  Total Day Minutes  Total Day Calls  \
# 0                               4              241.8              104
# 1                              11              122.6              115
# 2                              27              211.7              122
# 3                               2              243.6              108
# 4                               6              260.4              123
# ..                            ...                ...              ...
# 495                            10              152.8              144
# 496                             6              194.5              132
# 497                            26              262.3              104
# 498                            16              263.1              129
# 499                             7              250.1              101
#
#      Total Day Charge  Total Eve Minutes  Total Eve Calls  Total Eve Charge  \
# 0               37.49              209.8               90             14.84
# 1               44.85              245.3              129             29.08
# 2               24.56              188.6              112             13.29
# 3               45.82              111.1              116             15.07
# 4               27.97              219.6               60             27.35
# ..                ...                ...              ...               ...
# 495             31.13              132.3              125             20.39
# 496             25.84              208.4               85             28.89
# 497             41.85              163.9              148             18.75
# 498             20.10              149.3              104             27.67
# 499             21.20              162.7              114             21.56
#
#      Total Night Minutes  Total Night Calls  Total Night Charge  \
# 0                  160.8                 56               11.35
# 1                  151.9                 58                7.60
# 2                  235.5                131                5.66
# 3                  184.8                123               11.97
# 4                  137.8                107               10.90
# ..                   ...                ...                 ...
# 495                182.1                145               10.27
# 496                123.8                 61               14.53
# 497                117.9                 75               13.19
# 498                117.0                 68               11.65
# 499                236.7                146                9.72
#
#      Total Intl Minutes  Total Intl Calls  Total Intl Charge  \
# 0                  13.5                 3               1.80
# 1                   7.5                 5               3.15
# 2                  12.4                 6               1.66
# 3                   6.4                 2               3.69
# 4                  14.5                 1               3.12
# ..                  ...               ...                ...
# 495                13.9                 2               1.07
# 496                 7.4                 7               2.85
# 497                 8.8                 8               4.64
# 498                 6.9                 7               2.18
# 499                 8.3                 8               4.71
#
#      Customer service calls  Churn
# 0                       7.0  False
# 1                       6.0  False
# 2                       8.0  False
# 3                       8.0   True
# 4                       1.0  False
# ..                      ...    ...
# 495                     0.0  False
# 496                     2.0  False
# 497                     5.0  False
# 498                     6.0  False
# 499                     5.0  False
#
# [500 rows x 20 columns]

# %%
dataset['Churn'].value_counts()
# Out:
# Churn
# False    406
# True      94
# Name: count, dtype: int64

# %%
dataset.columns
# Out:
# Index(['State', 'Account Length', 'Area Code', 'International Plan',
#        'Voicemail Plan', 'Number of Voicemail Messages', 'Total Day Minutes',
#        'Total Day Calls', 'Total Day Charge', 'Total Eve Minutes',
#        'Total Eve Calls', 'Total Eve Charge', 'Total Night Minutes',
#        'Total Night Calls', 'Total Night Charge', 'Total Intl Minutes',
#        'Total Intl Calls', 'Total Intl Charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
print(dataset.groupby('Churn')['Customer service calls'].mean())
# Out:
# Churn
# False    4.432039
# True     4.693182
# Name: Customer service calls, dtype: float64

# %%
print(dataset.groupby('State')['Churn'].value_counts())
# Out:
# State  Churn
# CA     False    42
#        True     10
# FL     False    42
#        True      7
# IL     False    45
#        True      9
# KS     False    40
#        True     10
# NJ     False    44
#        True      1
# NY     False    30
#        True     11
# OH     False    38
#        True      5
# OK     False    59
#        True     12
# PA     False    39
#        True     12
# TX     False    33
#        True     11
# Name: count, dtype: int64

# %%
# Import matplotlib and seaborn 
import matplotlib.pyplot as plt 
import seaborn as sns 

# Visualize the distribution of 'Total day minutes' 
plt.hist(dataset['Total Day Minutes'], bins = 100) 

# Display the plot 
plt.show()

# %%
# Create the box plot 
sns.boxplot(x = 'Churn', 
			y = 'Customer service calls', 
			data = dataset, 				 
			hue = "International Plan") 
# Display the plot 
plt.show()

# %%
# Features and Labels 
X = dataset.iloc[:, 0:19].values 
y = dataset.iloc[:, 19].values # Churn 

# Encoding categorical data in X 
from sklearn.preprocessing import LabelEncoder 

labelencoder_X_1 = LabelEncoder() 
X[:, 3] = labelencoder_X_1.fit_transform(X[:, 3]) 

labelencoder_X_2 = LabelEncoder() 
X[:, 4] = labelencoder_X_2.fit_transform(X[:, 4]) 

# Encoding categorical data in y 
labelencoder_y = LabelEncoder() 
y = labelencoder_y.fit_transform(y)

# %%
# Removing extra column to avoid dummy variable trap 
X_State = pd.get_dummies(X[:, 0], drop_first = True) 

# Converting X to a dataframe 
X = pd.DataFrame(X) 

# Dropping the 'State' column 
X = X.drop([0], axis = 1) 

# Merging two dataframes 
frames = [X_State, X] 
result = pd.concat(frames, axis = 1, ignore_index = True) 

# Final dataset with all numeric features 
X = result

# %%
# Splitting the dataset into the Training and Test sets 
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y, 
													test_size = 0.2, 
													random_state = 0)

# %%
# Feature Scaling 
from sklearn.preprocessing import StandardScaler 
sc = StandardScaler() 
X_train = sc.fit_transform(X_train) 
X_test = sc.transform(X_test)

# %%
# Import RandomForestClassifier 
from sklearn.ensemble import RandomForestClassifier 

# Instantiate the classifier 
clf = RandomForestClassifier() 

# Fit to the training data 
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
# Predict the labels for the test set 
y_pred = clf.predict(X_test)

# %%
# Compute accuracy 
from sklearn.metrics import accuracy_score 

accuracy_score(y_test, y_pred)
# Out:
# 0.84

# %%
from sklearn.metrics import confusion_matrix 
print(confusion_matrix(y_test, y_pred))
# Out:
# [[84  1]
#  [15  0]]

# %%
# Confusion matrix values
TP = 0
TN = 84
FP = 1
FN = 15

# Precision, Recall, and Accuracy calculations
precision = TP / (TP + FP)
recall = TP / (TP + FN)
accuracy = (TP + TN) / (TP + TN + FP + FN)

# Print the results
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"Accuracy: {accuracy:.4f}")
# Out:
# Precision: 0.0000
# Recall: 0.0000
# Accuracy: 0.8400
